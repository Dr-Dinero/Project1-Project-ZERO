# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
#How Life Conditions, Enducation,

# %%
users = ["Avg Tot", "Avg Wht","Avg Blk","Avg Hisp","Avg Asi","Avg AInd","Other"]
bars_in_users = [23.3,19.5,27.7,38.3,14.9,32.1,16.1]
x_axis = np.arange(len(bars_in_users))
plt.bar(x_axis, bars_in_users, color='r', alpha=0.5, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, users)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.title("Average Percent of Highshool Male Dropouts")
plt.xlabel("Ethnicity")
plt.ylabel("Percent Per 1000 Males")
# Out:
# Text(0, 0.5, 'Percent Per 1000 Males')

# %%
use = ["Avg Wht","Avg Blk","Avg Hisp","Avg Asi","Other"]
White = 10.85
Hisp = 30.65
Blk = 35.34
Asa = 12.56
other = 22.12
demouser = [White,Hisp,Blk,Asa,other]
plt.bar(use, demouser, color='y', alpha=0.5, align="center")
plt.title("Average Percent of Young Males in Poverty")
plt.xlabel("Ethnicity")
plt.ylabel("Percent Per 1000 Males")
# Out:
# Text(0, 0.5, 'Percent Per 1000 Males')

# %%
#file paths stopped working and troubleshooting was becoming counterproductive in relation to time management
#samgoo =("Class_Folders/Project Data/Not-enrolled-nor-working.csv")
#samomo = pd.read_csv(samgoo,encoding="ISO-8859-1")
newusers = ["Avg WHT","Avg BLK","Avg HISP","Avg ASA","Avg PAC","Avg AmIn"]
avgwhite = 14.36
avghisp = 11.71
avgblk = 25.77
avgAsa = 8.25
avgpaci = 18.89
avgAmind = 30.71
#original code
#avgwhite = samomo.iloc[0,1]
#avghisp = samomo.iloc[0,2]
#avgblk = samomo.iloc[0,3]
#avgAsa = samomo.iloc[0,4]
#avgpaci = samomo.iloc[0,5]
#avgAmind = samomo.iloc[0,6]
usersnew = [avgwhite,avghisp,avgblk,avgAsa,avgpaci,avgAmind]
plt.bar(newusers, usersnew, color='g', alpha=0.5, align="center")
plt.title("Not Enrolled in School or Working")
plt.xlabel("Ethnicity")
plt.ylabel("Percent Per 1000 Males")
# Out:
# Text(0, 0.5, 'Percent Per 1000 Males')

# %%
# Labels for the sections of our pie chart
#avgtotl = samomo.iloc[0, 0]
#avgwhite = samomo.iloc[0,1]
#avghisp = samomo.iloc[0,1]
#avgblk = samomo.iloc[0,2]
#avgAsa = samomo.iloc[0,3]
#avgpaci = samomo.iloc[0,4]
#avgAmind = samomo.iloc[0,5]
labels = ["WHT", "HISP", "BLK","ASA","PACI","AmerI"]

# The values of each section of the pie chart
sizes = [avgwhite,avghisp,avgblk,avgAsa,avgpaci,avgAmind]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","blue","green"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0,0,0,0)
plt.pie(sizes,labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
# Out:
# (-1.1105930279931995,
#  1.1169119311856603,
#  -1.109112481141032,
#  1.1014713313857984)

# %%
#ewdata =("Class_Folders/Project Data/Regular_smoking_Alcohol_Illicit-drug_use.csv")
#itsdif = pd.read_csv(ewdata,encoding="ISO-8859-1")
#avgWHT= itsdif.iloc[0, 0]
#avgBlK = itsdif.iloc[0,1]
#avgHiSp = itsdif.iloc[0,2]
#avgAsA = itsdif.iloc[0,3]
#avgPaCi = itsdif.iloc[0,4]
#avgAmEr = itsdif.iloc[0,5]
#avgOthEr = itsdif.iloc[0,6]
avgWHT = 14.71
avgBlK = 6.65
avgHiSp = 8.33
avgAsA = 8.32
avgPaCi = 12.33
avgAmEr = 21.1
avgOthEr = 11.91
labels = ["AVG WHT", "AVG BLK", "AVG HIP", "AVG ASA","AVG PAC","AVG AMI","AVG OTH"]

# The values of each section of the pie chart
sizes = [avgWHT,avgBlK,avgHiSp,avgAsA,avgPaCi,avgAmEr,avgOthEr] 

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","lightyellow","lightgreen","purple"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0,0,0.1,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
# Out:
# (-1.2249670182227201,
#  1.187779361827557,
#  -1.106282802945108,
#  1.1714048897163634)

# %%
chac = [ 10 , 30 , 35 , 12 , 22 ]
chacca = [ 11 , 15 , 25 , 8 , 18 , 30]

# %%
#samgoo =("Class_Folders/Project Data/Not-enrolled-nor-working.csv")
#samomo = pd.read_csv(samgoo,encoding="ISO-8859-1")
x_axis = np.arange(1,7,1)
x_axis
#goodata =("Class_Folders/Project Data/Child-poverty.csv")
#gooata = pd.read_csv(goodata,encoding="ISO-8859-1")
chac = [ 10 , 30 , 35 , 12 , 22, 25]
chacca = [ 11 , 15 , 25 , 8 , 18 , 30]

druguse = plt.plot(x_axis,chac, marker="+" ,color="red",linewidth=1,label="Drug Use" )
poverty = plt.plot(x_axis,chacca, marker="s" ,color="blue",linewidth=1,label="Poverty")
plt.legend([druguse, poverty], ['druguse', 'poverty'])
plt.legend()
plt.title("Drug Use Vs Poverty Level")
plt.xlabel("Years")
plt.ylabel("Percentage")
# Out:
# /Users/rodneywalker/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x118c88e10>] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if sys.path[0] == '':
# /Users/rodneywalker/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x118fdb828>] instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if sys.path[0] == '':
# Text(0, 0.5, 'Percentage')
